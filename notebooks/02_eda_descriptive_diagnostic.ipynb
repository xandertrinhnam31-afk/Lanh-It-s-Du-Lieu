# %% [markdown]
# # Notebook 02 — EDA: Descriptive & Diagnostic
# **Phụ trách:** Thành viên 2 (Data Analyst)
#
# **Mục tiêu:**
# - Descriptive: Doanh thu theo thời gian, top sản phẩm, phân bố khách hàng
# - Diagnostic: Nguyên nhân tăng/giảm doanh thu, return rate, hiệu quả kênh

# %%
import sys
sys.path.append('../src')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from utils import load_all_data, parse_dates, set_seed

set_seed(42)
sns.set_theme(style='whitegrid', palette='muted')
plt.rcParams['figure.dpi'] = 120

# %%
dfs = parse_dates(load_all_data())
sales       = dfs['sales']
orders      = dfs['orders']
order_items = dfs['order_items']
products    = dfs['products']
customers   = dfs['customers']
geography   = dfs['geography']
returns     = dfs['returns']
reviews     = dfs['reviews']

# %% [markdown]
# ## DESCRIPTIVE
# ### 1. Doanh thu theo thời gian

# %%
# TODO: line chart doanh thu theo tháng/năm
# Đảm bảo: tiêu đề, nhãn trục x/y, chú thích

# %% [markdown]
# ### 2. Top sản phẩm / danh mục doanh thu cao nhất

# %%
# TODO: horizontal bar chart top 10 products/categories

# %% [markdown]
# ### 3. Phân bố khách hàng (region, age_group, gender)

# %%
# TODO: pie/bar charts

# %% [markdown]
# ### 4. Tỷ lệ trạng thái đơn hàng

# %%
# TODO: donut chart order_status

# %% [markdown]
# ### 5. Web traffic theo nguồn

# %%
# TODO: stacked area chart web_traffic by traffic_source

# %% [markdown]
# ## DIAGNOSTIC
# ### 6. Return rate theo category và size

# %%
# TODO: heatmap / grouped bar

# %% [markdown]
# ### 7. Phân tích payment method vs revenue

# %%
# TODO
