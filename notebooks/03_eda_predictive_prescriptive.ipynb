# %% [markdown]
# # Notebook 03 — EDA: Predictive & Prescriptive
# **Phụ trách:** Thành viên 3 (Business Analyst)
#
# **Mục tiêu:**
# - Predictive: Xu hướng mùa vụ, cohort analysis, chỉ số dẫn xuất
# - Prescriptive: Đề xuất hành động kinh doanh có số liệu hỗ trợ

# %%
import sys
sys.path.append('../src')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from statsmodels.tsa.seasonal import seasonal_decompose
from utils import load_all_data, parse_dates, set_seed

set_seed(42)
sns.set_theme(style='whitegrid', palette='muted')
plt.rcParams['figure.dpi'] = 120

# %%
dfs = parse_dates(load_all_data())
sales       = dfs['sales']
orders      = dfs['orders']
order_items = dfs['order_items']
products    = dfs['products']
customers   = dfs['customers']
inventory   = dfs['inventory']
web_traffic = dfs['web_traffic']
promotions  = dfs['promotions']
geography   = dfs['geography']

# %% [markdown]
# ## PREDICTIVE
# ### 1. Phân tích mùa vụ doanh thu (STL Decomposition)

# %%
# TODO: seasonal_decompose(sales.set_index('Date')['Revenue'], model='additive', period=365)

# %% [markdown]
# ### 2. Cohort retention analysis

# %%
# TODO: cohort heatmap by signup_date month

# %% [markdown]
# ### 3. Web traffic lag → doanh thu

# %%
# TODO: correlation analysis web_traffic sessions vs revenue (lag 0, 1, 7 ngày)

# %% [markdown]
# ### 4. Tồn kho: stockout trend theo tháng

# %%
# TODO: time series stockout_flag, overstock_flag by category

# %% [markdown]
# ## PRESCRIPTIVE
# ### 5. Đề xuất tối ưu tồn kho

# %%
# TODO: Identify top N sản phẩm có stockout_days cao nhất → ước tính doanh thu bị mất
# Công thức: lost_revenue = stockout_days * avg_daily_sales * price

# %% [markdown]
# ### 6. Đề xuất chiến lược khuyến mãi theo mùa

# %%
# TODO: so sánh doanh thu promo vs non-promo period theo tháng → tháng nào promo hiệu quả nhất

# %% [markdown]
# ### 7. Đề xuất kênh marketing tối ưu

# %%
# TODO: acquisition_channel → conversion rate, avg order value, retention rate
